# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
#same as in OpticalPlotting1, but with code changes from Scott and changed angles in plots too, 
#and constant error of 100 instead of 10, and sigma_theta_i = -1 in fits, no specular spike
# Out:
# Errors (log):  [ 0.01367153  0.01730093  0.01410181]
# Correlation matrix (log):
#  [[ 1.         -0.30260087 -0.18858042]
#  [-0.30260087  1.          0.82492059]
#  [-0.18858042  0.82492059  1.        ]]
# Fit reduced chi^2:  1.490096785
# Min and max values:
#  [[0.58764622931372734, 0.60393596306006059], [1.2163924940865258, 1.2240111275179], [0.072048558450512459, 0.074109514506732255]]
# Fit parameters (rho_L, n, gamma): [0.59573542066860441, 1.2201688592574642, 0.073071770798834493]
# Fitting time: 50.582313537597656
# Plotting time: 8.95305609703064
# Reflectance calc time: 11.556111812591553

# %%
# %run Vacuum_data_fitting.py
#Above, with constant error 10, no specular spike
# Out:
# Errors (log):  [ 0.00389906  0.00670133  0.00626958]
# Correlation matrix (log):
#  [[ 1.         -0.2380931  -0.15525011]
#  [-0.2380931   1.          0.69399578]
#  [-0.15525011  0.69399578  1.        ]]
# Fit reduced chi^2:  32.3127012251
# Min and max values:
#  [[0.57441173695349268, 0.57890858219933139], [1.1891164957810967, 1.1916682203125586], [0.061343868397070289, 0.062117911833870047]]
# Fit parameters (rho_L, n, gamma): [0.57665577621177244, 1.1903880830779865, 0.061729676887520964]
# Fitting time: 56.529818534851074
# Plotting time: 9.119768142700195
# Reflectance calc time: 14.251935482025146

# %%
# %run Vacuum_data_fitting.py
#Above, with sigma_theta_i = 2 in fits, no specular spike
# Out:
# Errors (log):  [ 0.00384736  0.00674611  0.00718468]
# Correlation matrix (log):
#  [[ 1.         -0.21746474 -0.13663936]
#  [-0.21746474  1.          0.71574103]
#  [-0.13663936  0.71574103  1.        ]]
# Fit reduced chi^2:  31.3721952466
# Min and max values:
#  [[0.57727998170022943, 0.58173911767095088], [1.1689681610620579, 1.1712633667548447], [0.053088938915264922, 0.053857299890975305]]
# Fit parameters (rho_L, n, gamma): [0.579505260721069, 1.1701118929935908, 0.053471739302673633]
# Fitting time: 248.889484167099
# Plotting time: 7.70172381401062
# Reflectance calc time: 15.000160694122314

# %%
# %run Vacuum_data_fitting.py
#Above, specular spike on
# Out:
# Errors (log):  [ 0.00387783  0.00776668  0.01271656  0.07043298]
# Correlation matrix (log):
#  [[ 1.         -0.2344319  -0.14453093  0.07232633]
#  [-0.2344319   1.          0.74963803 -0.45635784]
#  [-0.14453093  0.74963803  1.         -0.81029199]
#  [ 0.07232633 -0.45635784 -0.81029199  1.        ]]
# Fit reduced chi^2:  30.9790222126
# Min and max values:
#  [[0.57594399067668911, 0.58042818529110807], [1.1731541702816046, 1.1758648362128803], [0.055350364341463613, 0.05677615147598114], [8.4357925737045605, 9.7118775846226644]]
# Fit parameters (rho_L, n, gamma): [0.57818174075094209, 1.1745042400520731, 0.056058725191549648, 9.0513747466938774]
# Fitting time: 642.6479406356812
# Plotting time: 8.563676118850708
# Reflectance calc time: 17.16867160797119

# %%
# %run Vacuum_data_fitting.py
#Above, specular spike on, dark_bkg
# Out:
# Errors (log):  [ 0.00295491  0.00685181  0.00934604  0.03056501]
# Correlation matrix (log):
#  [[ 1.         -0.27408393 -0.16574586  0.08206412]
#  [-0.27408393  1.          0.68730439 -0.37644131]
#  [-0.16574586  0.68730439  1.         -0.76050588]
#  [ 0.08206412 -0.37644131 -0.76050588  1.        ]]
# Fit reduced chi^2:  4.09102510363
# Min and max values:
#  [[0.77565176517004597, 0.78024929189410008], [1.2407254867070319, 1.2440470040587364], [0.078678602594591876, 0.080163100346140409], [8.0381373315969125, 8.5448383275438928]]
# Fit parameters (rho_L, n, gamma): [0.77794713222065237, 1.242380555803126, 0.07941738295162068, 8.2876163010295478]
# Fitting time: 432.27031922340393
# Plotting time: 9.655024528503418
# Reflectance calc time: 13.094569206237793

# %%
# %run Vacuum_data_fitting.py
#Above, added 75 back
# Out:
# Errors (log):  [ 0.00295491  0.00685181  0.00934604  0.03056501]
# Correlation matrix (log):
#  [[ 1.         -0.27408393 -0.16574586  0.08206412]
#  [-0.27408393  1.          0.68730439 -0.37644131]
#  [-0.16574586  0.68730439  1.         -0.76050588]
#  [ 0.08206412 -0.37644131 -0.76050588  1.        ]]
# Fit reduced chi^2:  4.09102510363
# Min and max values:
#  [[0.77565176517004597, 0.78024929189410008], [1.2407254867070319, 1.2440470040587364], [0.078678602594591876, 0.080163100346140409], [8.0381373315969125, 8.5448383275438928]]
# Fit parameters (rho_L, n, gamma): [0.77794713222065237, 1.242380555803126, 0.07941738295162068, 8.2876163010295478]
# Fitting time: 425.83420395851135
# Plotting time: 8.825646877288818
# Reflectance calc time: 12.148990154266357

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133
# Out:
# Errors (log):  [ 0.00451548  0.01197387  0.01417873  0.01277075]
# Correlation matrix (log):
#  [[ 1.         -0.23012416 -0.18402486  0.02271563]
#  [-0.23012416  1.          0.659868    0.01584398]
#  [-0.18402486  0.659868    1.         -0.37315874]
#  [ 0.02271563  0.01584398 -0.37315874  1.        ]]
# Fit reduced chi^2:  6.45573325158
# Min and max values:
#  [[0.8310841616978264, 0.83862363921027205], [1.2144748580348996, 1.2196730389614312], [0.095211147302316917, 0.097949740218286771], [5.1523931949867672, 5.2856880427915343]]
# Fit parameters (rho_L, n, gamma): [0.83484538938239894, 1.2170583881017913, 0.096570736479261551, 5.2186150559800852]
# Fitting time: 1194.0899605751038
# Plotting time: 15.230449676513672
# Reflectance calc time: 18.555792093276978

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133
# Out:
# Errors (log):  [ 0.00470869  0.01226458  0.01225577  0.01185573]
# Correlation matrix (log):
#  [[ 1.         -0.27803567 -0.20433688 -0.00991153]
#  [-0.27803567  1.          0.66413495  0.10156165]
#  [-0.20433688  0.66413495  1.         -0.27680234]
#  [-0.00991153  0.10156165 -0.27680234  1.        ]]
# Fit reduced chi^2:  4.71694268739
# Min and max values:
#  [[0.82068842322170243, 0.82845367183674723], [1.2605872316712368, 1.2670582578671066], [0.10528695901515006, 0.10789959356957571], [5.5709118324226212, 5.7045847765350857]]
# Fit parameters (rho_L, n, gamma): [0.82456190650061545, 1.2638029039122438, 0.10658527143049018, 5.6373521116440175]
# Fitting time: 761.3690123558044
# Plotting time: 15.858856916427612
# Reflectance calc time: 18.02590537071228

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133
# Out:
# Errors (log):  [ 0.0042868   0.00896672  0.00914954]
# Correlation matrix (log):
#  [[ 1.         -0.10731531 -0.06046945]
#  [-0.10731531  1.          0.53898973]
#  [-0.06046945  0.53898973  1.        ]]
# Fit reduced chi^2:  9.34755592975
# Min and max values:
#  [[0.85330147204516271, 0.86064878494807873], [1.1610152909869935, 1.1639288949684603], [0.05341605409865538, 0.054402516392655455]]
# Fit parameters (rho_L, n, gamma): [0.85696725439778398, 1.1624655616569952, 0.053907028843491925]
# Fitting time: 689.6034381389618
# Plotting time: 13.575632810592651
# Reflectance calc time: 24.203301668167114

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133
# Out:
# Errors (log):  [ 0.00835924  0.01500166  0.01610421  0.01904341]
# Correlation matrix (log):
#  [[ 1.         -0.31094918 -0.20614085  0.04329777]
#  [-0.31094918  1.          0.76986473 -0.2085253 ]
#  [-0.20614085  0.76986473  1.         -0.52497274]
#  [ 0.04329777 -0.2085253  -0.52497274  1.        ]]
# Fit reduced chi^2:  1.89406092495
# Min and max values:
#  [[0.67526701654903998, 0.68665134982097897], [1.2897346339868501, 1.2985593575294838], [0.086483819854253227, 0.089314671197679996], [6.3671561450978897, 6.6143381550612039]]
# Fit parameters (rho_L, n, gamma): [0.68093539223848809, 1.294113900006705, 0.087887848615164174, 6.4895703886893301]
# Fitting time: 622.1186695098877
# Plotting time: 12.384135723114014
# Reflectance calc time: 15.298803091049194

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133, without specular spike
# Out:
# Errors (log):  [ 0.00767598  0.01111568  0.01055804]
# Correlation matrix (log):
#  [[ 1.         -0.19800867 -0.10547216]
#  [-0.19800867  1.          0.6642775 ]
#  [-0.10547216  0.6642775   1.        ]]
# Fit reduced chi^2:  3.31321413445
# Min and max values:
#  [[0.700695417137711, 0.71153546161377101], [1.2186408017151664, 1.2235559176898099], [0.059738938247192418, 0.061013802672294205]]
# Fit parameters (rho_L, n, gamma): [0.7060946374840521, 1.2210847011257671, 0.060373005474852477]
# Fitting time: 462.088725566864
# Plotting time: 11.984410285949707
# Reflectance calc time: 18.7938449382782

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133
# Out:
# Errors (log):  [ 0.00448506  0.00918649  0.00846189]
# Correlation matrix (log):
#  [[ 1.         -0.17377678 -0.11055715]
#  [-0.17377678  1.          0.59286052]
#  [-0.11055715  0.59286052  1.        ]]
# Fit reduced chi^2:  3.33645483737
# Min and max values:
#  [[0.83705567198302844, 0.84459793448231246], [1.2145556198572109, 1.2185340817337948], [0.067777672222035207, 0.068934487591200369]]
# Fit parameters (rho_L, n, gamma): [0.84081834637665342, 1.2165357138356643, 0.068353632710707726]
# Fitting time: 381.4306538105011
# Plotting time: 14.11325216293335
# Reflectance calc time: 18.928703546524048

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133
# Out:
# Errors (log):  [ 0.00461475  0.0106643   0.01253295  0.02525684]
# Correlation matrix (log):
#  [[ 1.         -0.23241568 -0.16671874  0.07271098]
#  [-0.23241568  1.          0.67519491 -0.2974122 ]
#  [-0.16671874  0.67519491  1.         -0.64019923]
#  [ 0.07271098 -0.2974122  -0.64019923  1.        ]]
# Fit reduced chi^2:  2.39422379681
# Min and max values:
#  [[0.82833702671770015, 0.83601756047933373], [1.2410944774285713, 1.2462919150613139], [0.080343068079856764, 0.082382391942577154], [7.5650354970212339, 7.9569894670962906]]
# Fit parameters (rho_L, n, gamma): [0.83216843266927421, 1.243679339617846, 0.081356340407026176, 7.7585377338779189]
# Fitting time: 559.9138250350952
# Plotting time: 12.818408966064453
# Reflectance calc time: 14.640088319778442

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133
# Out:
# Errors (log):  [ 0.00519189  0.01483363  0.02196123  0.05809754]
# Correlation matrix (log):
#  [[ 1.         -0.21330878 -0.15784292  0.11364758]
#  [-0.21330878  1.          0.72043395 -0.53461596]
#  [-0.15784292  0.72043395  1.         -0.80173882]
#  [ 0.11364758 -0.53461596 -0.80173882  1.        ]]
# Fit reduced chi^2:  3.37980806498
# Min and max values:
#  [[0.92055289176105659, 0.93016150660253005], [1.1482111746628232, 1.1526740675047626], [0.060367387830744974, 0.063077963658705646], [8.4335638954877563, 9.4727052628973816]]
# Fit parameters (rho_L, n, gamma): [0.92534472749769325, 1.1504260711626546, 0.061707794448989356, 8.938045932851777]
# Fitting time: 679.7256710529327
# Plotting time: 8.055308103561401
# Reflectance calc time: 19.912795066833496

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133
# Out:
# Errors (log):  [ 0.00521425  0.01483024  0.0219068   0.05740394]
# Correlation matrix (log):
#  [[ 1.         -0.21846722 -0.16063494  0.11530355]
#  [-0.21846722  1.          0.72280558 -0.53402084]
#  [-0.16063494  0.72280558  1.         -0.79955697]
#  [ 0.11530355 -0.53402084 -0.79955697  1.        ]]
# Fit reduced chi^2:  3.77234570353
# Min and max values:
#  [[0.90896378235709963, 0.91849251904579343], [1.1479907077196998, 1.1524459294961891], [0.060580508840196438, 0.063293763952511517], [8.3956078582594671, 9.4170000125897868]]
# Fit parameters (rho_L, n, gamma): [0.9137157294140037, 1.1502018009050772, 0.061922277305138176, 8.891649976631351]
# Fitting time: 776.570220708847
# Plotting time: 9.471299886703491
# Reflectance calc time: 23.09002161026001

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133
# Out:
# Errors (log):  [ 0.00508128  0.01147511  0.01171599]
# Correlation matrix (log):
#  [[ 1.         -0.14567016 -0.07126693]
#  [-0.14567016  1.          0.49347107]
#  [-0.07126693  0.49347107  1.        ]]
# Fit reduced chi^2:  3.8663313328
# Min and max values:
#  [[0.92675744220714662, 0.93622368748435114], [1.1341577328795021, 1.1372722858929991], [0.051917041328477243, 0.053147925058019366]]
# Fit parameters (rho_L, n, gamma): [0.93147853971347094, 1.1357060745235512, 0.052528877979260154]
# Fitting time: 290.7920632362366
# Plotting time: 9.255081176757812
# Reflectance calc time: 25.113396883010864

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133 255nm
# Out:
# Errors (log):  [ 0.00533771  0.01274742  0.01239712]
# Correlation matrix (log):
#  [[ 1.         -0.23688423 -0.15149799]
#  [-0.23688423  1.          0.62068821]
#  [-0.15149799  0.62068821  1.        ]]
# Fit reduced chi^2:  2.1319863655
# Min and max values:
#  [[0.90520581992921823, 0.91492104033879385], [1.1703132920372066, 1.1747112260595896], [0.066389981572087864, 0.068056646594377559]]
# Fit parameters (rho_L, n, gamma): [0.91005046590305705, 1.1724982436608133, 0.067218148689612262]
# Fitting time: 227.42557334899902
# Plotting time: 8.479037046432495
# Reflectance calc time: 17.237440824508667

# %%
print(y_total)
# Out:
# [0.8655918123135576, 0.8657854651372088, 0.8665217415069081, 0.8693948859742252]

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, no correction factor 255nm
# Out:
# Errors (log):  [ 0.00535759  0.01310702  0.01251102]
# Correlation matrix (log):
#  [[ 1.         -0.23899751 -0.15324548]
#  [-0.23899751  1.          0.63232232]
#  [-0.15324548  0.63232232  1.        ]]
# Fit reduced chi^2:  2.07045867968
# Min and max values:
#  [[0.9729783413349169, 0.98346004206696802], [1.1831229624413908, 1.1879868289120541], [0.067103334887477634, 0.068803579661964404]]
# Fit parameters (rho_L, n, gamma): [0.97820515256232743, 1.1855389582010696, 0.067948139396999258]
# Fitting time: 222.25950717926025
# Plotting time: 9.11183762550354
# Reflectance calc time: 19.943718194961548

# %%
print(y_total)
# Out:
# [0.9275514540496373, 0.9277350873206796, 0.9283274554472214, 0.9301550522857424]

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133 310nm
# Out:
# Errors (log):  [ 0.00476401  0.01106049  0.02858097]
# Correlation matrix (log):
#  [[ 1.         -0.01860414  0.00134053]
#  [-0.01860414  1.          0.10029549]
#  [ 0.00134053  0.10029549  1.        ]]
# Fit reduced chi^2:  18.455702529
# Min and max values:
#  [[0.89751971253521345, 0.90611216651007753], [1.045706602654811, 1.0467289432447415], [0.0098862563767588459, 0.010467837788583638]]
# Fit parameters (rho_L, n, gamma): [0.90180570590941833, 1.046214946082048, 0.010172891825251176]
# Fitting time: 244.14924001693726
# Plotting time: 8.05331540107727
# Reflectance calc time: 49.44168424606323

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133 310nm
# Out:
# Errors (log):  [ 0.00490894  0.01000926  0.01138957]
# Correlation matrix (log):
#  [[ 1.         -0.06404487 -0.01742501]
#  [-0.06404487  1.          0.32931199]
#  [-0.01742501  0.32931199  1.        ]]
# Fit reduced chi^2:  9.04310729779
# Min and max values:
#  [[0.91936788055031593, 0.92843858143352442], [1.1113569990514389, 1.1136086644577654], [0.030947230166146408, 0.031660271886961494]]
# Fit parameters (rho_L, n, gamma): [0.92389209912937409, 1.1124771974235608, 0.031301720738780028]
# Fitting time: 254.9758322238922
# Plotting time: 8.744110822677612
# Reflectance calc time: 28.42107605934143

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133 310nm
# Out:
# Errors (log):  [ 0.00500771  0.01078519  0.01146857]
# Correlation matrix (log):
#  [[ 1.         -0.1105733  -0.06499664]
#  [-0.1105733   1.          0.44102402]
#  [-0.06499664  0.44102402  1.        ]]
# Fit reduced chi^2:  7.73213866364
# Min and max values:
#  [[0.91377340028882359, 0.92297120172710834], [1.1338234029176044, 1.1367413836734093], [0.045571524386161244, 0.046628884621005]]
# Fit parameters (rho_L, n, gamma): [0.91836078605896576, 1.1352745256241448, 0.046097172935068681]
# Fitting time: 253.1448528766632
# Plotting time: 8.38295578956604
# Reflectance calc time: 22.743377447128296

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133 310nm
# Out:
# Errors (log):  [ 0.00495661  0.01027588  0.01110716]
# Correlation matrix (log):
#  [[ 1.         -0.0847544  -0.03819505]
#  [-0.0847544   1.          0.3853778 ]
#  [-0.03819505  0.3853778   1.        ]]
# Fit reduced chi^2:  7.90650511904
# Min and max values:
#  [[0.91732062688130578, 0.9264594599321222], [1.1247476359682584, 1.1273379467496329], [0.037925301819415329, 0.038777214145613664]]
# Fit parameters (rho_L, n, gamma): [0.92187871901083085, 1.126036136984869, 0.038348892424534244]
# Fitting time: 248.3443100452423
# Plotting time: 8.058080673217773
# Reflectance calc time: 24.470534086227417

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133 310nm
# Out:
# Errors (log):  [ 0.00490894  0.01000926  0.01138957]
# Correlation matrix (log):
#  [[ 1.         -0.06404487 -0.01742501]
#  [-0.06404487  1.          0.32931199]
#  [-0.01742501  0.32931199  1.        ]]
# Fit reduced chi^2:  9.04310729779
# Min and max values:
#  [[0.91936788055031593, 0.92843858143352442], [1.1113569990514389, 1.1136086644577654], [0.030947230166146408, 0.031660271886961494]]
# Fit parameters (rho_L, n, gamma): [0.92389209912937409, 1.1124771974235608, 0.031301720738780028]
# Fitting time: 270.26248598098755
# Plotting time: 9.009066104888916
# Reflectance calc time: 32.13413596153259

# %%
print(y_total)
# Out:
# [0.8957765186607349, 0.8958234401405831, 0.8960672406162926, 0.8974323228021261]

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, without correction factor 310nm
# Out:
# Errors (log):  [ 0.00491733  0.01017929  0.01136257]
# Correlation matrix (log):
#  [[ 1.         -0.06372418 -0.01779721]
#  [-0.06372418  1.          0.3464956 ]
#  [-0.01779721  0.3464956   1.        ]]
# Fit reduced chi^2:  8.82612582264
# Min and max values:
#  [[0.98856040928777422, 0.99833052295158276], [1.1195900895325406, 1.1220497256277639], [0.031672034425591925, 0.032400026402460702]]
# Fit parameters (rho_L, n, gamma): [0.99343345543297179, 1.1208136482987179, 0.032033962471240157]
# Fitting time: 263.31329321861267
# Plotting time: 8.938404321670532
# Reflectance calc time: 26.476043939590454

# %%
print(y_total)
# Out:
# [0.9612199201201036, 0.9612558505665166, 0.9614065735928903, 0.962118677849977]

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133 310nm
# Out:
# Errors (log):  [ 0.00490002  0.00969899  0.01148725]
# Correlation matrix (log):
#  [[ 1.         -0.06202366 -0.03015688]
#  [-0.06202366  1.          0.31750494]
#  [-0.03015688  0.31750494  1.        ]]
# Fit reduced chi^2:  8.19518593905
# Min and max values:
#  [[0.90326382797811122, 0.91215935973515905], [1.1047054372294809, 1.106756339003667], [0.031075809131718656, 0.031798024892566633]]
# Fit parameters (rho_L, n, gamma): [0.9077006968161051, 1.1057259152355638, 0.031434842966476535]
# Fitting time: 253.37696933746338
# Plotting time: 8.309092283248901
# Reflectance calc time: 24.940980195999146

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133 500nm
# Out:
# Errors (log):  [ 0.00934368  0.01744625  0.0282794 ]
# Correlation matrix (log):
#  [[ 1.         -0.10038257 -0.08936224]
#  [-0.10038257  1.          0.6756693 ]
#  [-0.08936224  0.6756693   1.        ]]
# Fit reduced chi^2:  26.5806556467
# Min and max values:
#  [[0.51133890484120303, 0.52098431752668051], [1.0504992901152452, 1.052292438882483], [0.052562842132722616, 0.055621412580041642]]
# Fit parameters (rho_L, n, gamma): [0.51613908044589529, 1.0513880437646759, 0.054070505163571023]
# Fitting time: 413.6794192790985
# Plotting time: 8.834677457809448
# Reflectance calc time: 16.392069816589355

# %%
# %run Vacuum_data_fitting.py
#solid angle 2.0, correction factor 0.93133 500nm
# Out:
# Errors (log):  [ 0.00960783  0.02367797  0.0167745 ]
# Correlation matrix (log):
#  [[ 1.         -0.19340089 -0.16817092]
#  [-0.19340089  1.          0.70823075]
#  [-0.16817092  0.70823075  1.        ]]
# Fit reduced chi^2:  26.7356784154
# Min and max values:
#  [[0.4968779767397572, 0.50651813856455385], [1.0861009952699943, 1.0902764757139451], [0.11933509570743393, 0.12340658478577458]]
# Fit parameters (rho_L, n, gamma): [0.50167490257331337, 1.0881640199199092, 0.12135376634591104]
# Fitting time: 320.9536945819855
# Plotting time: 8.303082466125488
# Reflectance calc time: 8.40190315246582

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, for comparison with calibration by Labsphere 500nm
# Out:
# Errors (log):  [ 0.00835924  0.01500166  0.01610421  0.01904341]
# Correlation matrix (log):
#  [[ 1.         -0.31094918 -0.20614085  0.04329777]
#  [-0.31094918  1.          0.76986473 -0.2085253 ]
#  [-0.20614085  0.76986473  1.         -0.52497274]
#  [ 0.04329777 -0.2085253  -0.52497274  1.        ]]
# Fit reduced chi^2:  1.89406092495
# Min and max values:
#  [[0.67526701654903998, 0.68665134982097897], [1.2897346339868501, 1.2985593575294838], [0.086483819854253227, 0.089314671197679996], [6.3671561450978897, 6.6143381550612039]]
# Fit parameters (rho_L, n, gamma): [0.68093539223848809, 1.294113900006705, 0.087887848615164174, 6.4895703886893301]
# Fitting time: 665.179205417633
# Plotting time: 13.236701726913452
# Reflectance calc time: 17.421929597854614

# %%
print(y_total)
# Out:
# [0.63535793689678521, 0.63603148318052205, 0.63869909789416468, 0.64867413308310329]

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, for comparison with calibration by Labsphere 500nm no correction factor
# Out:
# Errors (log):  [ 0.00845304  0.01530573  0.01598705  0.01954679]
# Correlation matrix (log):
#  [[ 1.         -0.31374928 -0.20679479  0.0434609 ]
#  [-0.31374928  1.          0.7741391  -0.21403782]
#  [-0.20679479  0.7741391   1.         -0.52762107]
#  [ 0.0434609  -0.21403782 -0.52762107  1.        ]]
# Fit reduced chi^2:  1.57046017489
# Min and max values:
#  [[0.72404206603212262, 0.73638683341436106], [1.316164487199962, 1.3259923979471291], [0.086667240059378842, 0.089483124529457558], [6.4491155787192369, 6.7062275274867069]]
# Fit parameters (rho_L, n, gamma): [0.73018836218073657, 1.3210408374771658, 0.088063928113943396, 6.5764151649626186]
# Fitting time: 600.9844284057617
# Plotting time: 12.256697654724121
# Reflectance calc time: 17.210412979125977

# %%
print(y_total)
# Out:
# [0.67790846768261104, 0.67860201564841305, 0.68121102341158213, 0.69040251151705867]

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, for comparison with calibration by Labsphere 400nm
# Out:
# Errors (log):  [ 0.00461475  0.0106643   0.01253295  0.02525684]
# Correlation matrix (log):
#  [[ 1.         -0.23241568 -0.16671874  0.07271098]
#  [-0.23241568  1.          0.67519491 -0.2974122 ]
#  [-0.16671874  0.67519491  1.         -0.64019923]
#  [ 0.07271098 -0.2974122  -0.64019923  1.        ]]
# Fit reduced chi^2:  2.39422379681
# Min and max values:
#  [[0.82833702671770015, 0.83601756047933373], [1.2410944774285713, 1.2462919150613139], [0.080343068079856764, 0.082382391942577154], [7.5650354970212339, 7.9569894670962906]]
# Fit parameters (rho_L, n, gamma): [0.83216843266927421, 1.243679339617846, 0.081356340407026176, 7.7585377338779189]
# Fitting time: 542.7846562862396
# Plotting time: 12.435312032699585
# Reflectance calc time: 14.296239852905273

# %%
print(y_total)
# Out:
# [0.78001161079118086, 0.7804285038398262, 0.78195784130949519, 0.78728818504227538]

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, for comparison with calibration by Labsphere 400nm
# Out:
# Errors (log):  [ 0.00464023  0.01097324  0.01246975  0.0253544 ]
# Correlation matrix (log):
#  [[ 1.         -0.23229003 -0.16575947  0.07012419]
#  [-0.23229003  1.          0.68382741 -0.2944831 ]
#  [-0.16575947  0.68382741  1.         -0.63224591]
#  [ 0.07012419 -0.2944831  -0.63224591  1.        ]]
# Fit reduced chi^2:  2.10876547804
# Min and max values:
#  [[0.8909022016584166, 0.89920867430716978], [1.2629503516803062, 1.2687849755890748], [0.081381864701966219, 0.083437008238686841], [7.5991152230876118, 7.994394629550194]]
# Fit parameters (rho_L, n, gamma): [0.89504580200713957, 1.2658516576166674, 0.082403029772076059, 7.7942495423731932]
# Fitting time: 548.1566758155823
# Plotting time: 11.758208513259888
# Reflectance calc time: 15.730619668960571

# %%
print(y_total)
# Out:
# [0.83489642991583202, 0.83531533637227084, 0.8366936632961165, 0.84081132924009272]
