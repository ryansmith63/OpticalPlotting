# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
#August data
# Out:
# Errors (log):  [ 0.00610153  0.01874252  0.00972414]
# Correlation matrix (log):
#  [[ 1.         -0.17103934 -0.04993941]
#  [-0.17103934  1.          0.78014131]
#  [-0.04993941  0.78014131  1.        ]]
# Fit reduced chi^2:  7.8026403894
# Min and max values:
#  [[1.1708177911530109, 1.1851928746388078], [1.7837208169215695, 1.8136561830942117], [0.15817047771829607, 0.16127673057478542]]
# Fit parameters (rho_L, n, gamma): [1.1779834054751774, 1.7985482380594684, 0.15971605279325787]
# Fitting time: 245.18377375602722
# Plotting time: 8.346221446990967
# Reflectance calc time: 8.50817322731018

# %%
# %run Vacuum_data_fitting.py
#After 3rd run
# Out:
# Errors (log):  [0.00467375 0.01568182 0.00830074]
# Correlation matrix (log):
#  [[ 1.         -0.20703341 -0.08068786]
#  [-0.20703341  1.          0.77503787]
#  [-0.08068786  0.77503787  1.        ]]
# Fit reduced chi^2:  4.028813775519514
# Min and max values:
#  [[1.1734732192201696, 1.1844936905210737], [1.5593764261299503, 1.5771985299435647], [0.1517810248256041, 0.1543218479903473]]
# Fit parameters (rho_L, n, gamma): [1.1789705781578026, 1.56821760870928, 0.15304616375772379]
# Fitting time: 310.3130714893341
# Plotting time: 10.10954213142395
# Reflectance calc time: 6.220667123794556

# %%
# %run Vacuum_data_fitting.py
#After 3rd run with spike
# Out:
# Errors (log):  [0.00467885 0.01687971 0.01020606 0.02254157]
# Correlation matrix (log):
#  [[ 1.         -0.2067759  -0.0845706  -0.00713102]
#  [-0.2067759   1.          0.79162953 -0.12776922]
#  [-0.0845706   0.79162953  1.         -0.38268454]
#  [-0.00713102 -0.12776922 -0.38268454  1.        ]]
# Fit reduced chi^2:  3.321281394265169
# Min and max values:
#  [[1.1673471955895058, 1.1783221515923519], [1.554124105824851, 1.5731503597670027], [0.15228932500198505, 0.15542981679270784], [10.867905005387204, 11.369076595238583]]
# Fit parameters (rho_L, n, gamma): [1.1728218360698799, 1.5635569453117244, 0.15385155795292968, 11.11566662130634]
# Fitting time: 695.3879091739655
# Plotting time: 12.996776580810547
# Reflectance calc time: 8.93201208114624

# %%
# %run Vacuum_data_fitting.py
#September 21
# Out:
# Errors (log):  [0.00645262 0.01750096 0.00962211]
# Correlation matrix (log):
#  [[ 1.         -0.33740134 -0.18052649]
#  [-0.33740134  1.          0.77114395]
#  [-0.18052649  0.77114395  1.        ]]
# Fit reduced chi^2:  4.891272497400784
# Min and max values:
#  [[0.9154351613039834, 0.9273256224736374], [1.5874092435035592, 1.608333759802047], [0.14836333847366773, 0.15124612439606736]]
# Fit parameters (rho_L, n, gamma): [0.9213612108128229, 1.5977799541997006, 0.14979779686832578]
# Fitting time: 209.44806551933289
# Plotting time: 6.732616662979126
# Reflectance calc time: 7.072709083557129

# %%
# %run Vacuum_data_fitting.py
#after 3rd run, for comparison with Labsphere calibration, 400nm
# Out:
# Errors (log):  [ 0.00533302  0.01852343  0.01210567]
# Correlation matrix (log):
#  [[ 1.         -0.32191873 -0.18757261]
#  [-0.32191873  1.          0.81384382]
#  [-0.18757261  0.81384382  1.        ]]
# Fit reduced chi^2:  8.62793100469
# Min and max values:
#  [[0.87400796351886223, 0.88338006390756985], [1.2841642028792544, 1.2948890257848635], [0.13994197947451081, 0.14337151065011658]]
# Fit parameters (rho_L, n, gamma): [0.87868151833813912, 1.2894769506368264, 0.14164636599866662]
# Fitting time: 636.1949019432068
# Plotting time: 12.080053091049194
# Reflectance calc time: 9.057587623596191

# %%
print(y_total)
# Out:
# [0.8013012919061495, 0.8021012422622853, 0.8041469432974904, 0.8081559670135573]

# %%
# %run Vacuum_data_fitting.py
#after 3rd run, for comparison with Labsphere calibration, 400nm no correction factor
# Out:
# Errors (log):  [ 0.00533777  0.01893064  0.01217427]
# Correlation matrix (log):
#  [[ 1.         -0.31106667 -0.17641695]
#  [-0.31106667  1.          0.81538137]
#  [-0.17641695  0.81538137  1.        ]]
# Fit reduced chi^2:  8.63998306374
# Min and max values:
#  [[0.94157088423153723, 0.95167650643165203], [1.3049631337910168, 1.3167307942711601], [0.13939122516574215, 0.14282685334518661]]
# Fit parameters (rho_L, n, gamma): [0.94661020999312639, 1.3107912733476454, 0.1410985828219169]
# Fitting time: 586.6798543930054
# Plotting time: 12.702895164489746
# Reflectance calc time: 10.373091459274292

# %%
print(y_total)
# Out:
# [0.8593681967277496, 0.8601631039650689, 0.8619525556604589, 0.8642643783246553]

# %%
# %run Vacuum_data_fitting.py
#after 3rd run, for comparison with Labsphere calibration, 500nm
# Out:
# Errors (log):  [ 0.01401211  0.02453339  0.01328282]
# Correlation matrix (log):
#  [[ 1.         -0.48640274 -0.3189214 ]
#  [-0.48640274  1.          0.85503251]
#  [-0.3189214   0.85503251  1.        ]]
# Fit reduced chi^2:  9.40201649503
# Min and max values:
#  [[0.53031604549063871, 0.5453879452368785], [1.3628923159934183, 1.3811423476907807], [0.14862552598493628, 0.1526267696145957]]
# Fit parameters (rho_L, n, gamma): [0.53779919893607731, 1.3719054036669487, 0.15061286104895216]
# Fitting time: 627.2165997028351
# Plotting time: 12.666483402252197
# Reflectance calc time: 7.1131508350372314

# %%
print(y_total)
# Out:
# [0.4926538928307524, 0.4940793977830849, 0.49875267873156165, 0.5133540210286]

# %%
# %run Vacuum_data_fitting.py
#after 3rd run, for comparison with Labsphere calibration, 400nm no correction factor no 75
# Out:
# Errors (log):  [ 0.0058165   0.02298333  0.01527701]
# Correlation matrix (log):
#  [[ 1.         -0.36255564 -0.21809957]
#  [-0.36255564  1.          0.84092718]
#  [-0.21809957  0.84092718  1.        ]]
# Fit reduced chi^2:  2.38047816919
# Min and max values:
#  [[0.92870948509361018, 0.93957624011250418], [1.2974920226540345, 1.3114858969590153], [0.14622989692461338, 0.15076676427894084]]
# Fit parameters (rho_L, n, gamma): [0.93412706103670606, 1.3044085569009907, 0.14848100349932647]
# Fitting time: 590.9048588275909
# Plotting time: 10.414861917495728
# Reflectance calc time: 8.48988151550293

# %%
print(y_total)
# Out:
# [0.8468128636158975, 0.8476420528562753, 0.8495077717823886, 0.8519199736216448]

# %%
# %run Vacuum_data_fitting.py
#after 3rd run, for comparison with Labsphere calibration, 400nm with correction factor no 75
# Out:
# Errors (log):  [ 0.00578371  0.02234794  0.01534884]
# Correlation matrix (log):
#  [[ 1.         -0.36966115 -0.22747188]
#  [-0.36966115  1.          0.83894977]
#  [-0.22747188  0.83894977  1.        ]]
# Fit reduced chi^2:  2.51829660032
# Min and max values:
#  [[0.86439275878036537, 0.87444960246379888], [1.2712850854599966, 1.2836854679834429], [0.14477531438842647, 0.14928849704764002]]
# Fit parameters (rho_L, n, gamma): [0.8694066392017471, 1.2774159988638858, 0.14701458803345932]
# Fitting time: 685.2571678161621
# Plotting time: 9.790781021118164
# Reflectance calc time: 8.117451667785645

# %%
print(y_total)
# Out:
# [0.7928651232634816, 0.7936643351072635, 0.7957110050343775, 0.799719322304772]

# %%
# %run Vacuum_data_fitting.py
#after 3rd run, for comparison with Labsphere calibration, 500nm with correction factor no 75
# Out:
# Errors (log):  [ 0.0146771   0.03122439  0.01841027]
# Correlation matrix (log):
#  [[ 1.         -0.49874626 -0.34653443]
#  [-0.49874626  1.          0.89027672]
#  [-0.34653443  0.89027672  1.        ]]
# Fit reduced chi^2:  3.54376572274
# Min and max values:
#  [[0.57372041741239155, 0.59081113761659576], [1.3516158789243351, 1.3742739856628998], [0.14699989338523001, 0.15251339144481343]]
# Fit parameters (rho_L, n, gamma): [0.58220306808302136, 1.3627680752593516, 0.14973126688239641]
# Fitting time: 610.4531650543213
# Plotting time: 9.604960918426514
# Reflectance calc time: 8.23353123664856

# %%
print(y_total)
# Out:
# [0.5318022643252299, 0.5331464900569214, 0.5374575314367928, 0.5505760122081458]
