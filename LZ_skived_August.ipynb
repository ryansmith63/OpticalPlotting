# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
# Out:
# Errors (log):  [ 0.00766278  0.01175057  0.00999676  0.03659556]
# Correlation matrix (log):
#  [[ 1.         -0.33274523 -0.29427028  0.09653945]
#  [-0.33274523  1.          0.73709341 -0.23168481]
#  [-0.29427028  0.73709341  1.         -0.42736677]
#  [ 0.09653945 -0.23168481 -0.42736677  1.        ]]
# Fit reduced chi^2:  9.92636510372
# Min and max values:
#  [[0.7944597866226909, 0.80672910881730675], [1.9144871354570472, 1.9362331603676191], [0.10681767811956502, 0.10897483197645033], [9.3801077224087308, 10.092397004523303]]
# Fit parameters (rho_L, n, gamma): [0.80057094354798508, 1.9252962665787008, 0.1078908639561022, 9.7297364342382764]
# Fitting time: 381.77015709877014
# Plotting time: 8.216620922088623
# Reflectance calc time: 15.57573676109314
