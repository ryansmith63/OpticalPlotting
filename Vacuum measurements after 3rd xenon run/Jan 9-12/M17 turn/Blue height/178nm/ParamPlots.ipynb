# %%
import matplotlib.pyplot as plt

Augustalbedo = [0.987, 0.986, 0.801, 0.692, 0.672, 0.844, 1.178]
Augustindex = [1.62, 1.59, 1.93, 1.92, 1.67, 1.69, 1.8]
Augustlabels = ['M18 turn','M18 polished','LZ Skived','807NX','LUX','NXT85','M17 turn']

After3rdalbedo = [0.698, 1.173]
After3rdindex = [1.73, 1.56]
After3rdlabels = ['LZ Skived','M17 turn']

After1stalbedo = [0.634, 0.742]
After1stindex = [1.32, 1.31]
After1stlabels = ['LUX','M18 turn']

Before2ndalbedo = [0.89]
Before2ndindex = [1.57]
Before2ndlabels = ['NXT85']

Oct1albedo = [0.834]
Oct1index = [1.7]
Oct1labels = ['M18 polished']

plt.scatter(Augustindex, Augustalbedo, c='r')
for i in range(len(Augustlabels)):
    plt.annotate(Augustlabels[i],(Augustindex[i],Augustalbedo[i]))
plt.scatter(After3rdindex, After3rdalbedo, c='g')
for i in range(len(After3rdlabels)):
    plt.annotate(After3rdlabels[i],(After3rdindex[i],After3rdalbedo[i]))
plt.scatter(After1stindex, After1stalbedo, c='b')
for i in range(len(After1stlabels)):
    plt.annotate(After1stlabels[i],(After1stindex[i],After1stalbedo[i]))
plt.scatter(Before2ndindex, Before2ndalbedo,c='m')
for i in range(len(Before2ndlabels)):
    plt.annotate(Before2ndlabels[i],(Before2ndindex[i],Before2ndalbedo[i]))
plt.scatter(Oct1index, Oct1albedo, c='c')
for i in range(len(Oct1labels)):
    plt.annotate(Oct1labels[i],(Oct1index[i],Oct1albedo[i]))
    
plt.legend(['August','After 3rd run','After 1st run','Before 2nd run','Oct 1'])

# %%
import matplotlib.pyplot as plt

Augustalbedo = []
Augustindex = []
Augustlabels = []

After3rdalbedo = [0.688]
After3rdindex = [1.73]
After3rdlabels = ['LZ Skived']

After1stalbedo = [0.645]
After1stindex = [1.34]
After1stlabels = ['LUX']

Before2ndalbedo = [0.89]
Before2ndindex = [1.57]
Before2ndlabels = ['NXT85']

Oct1albedo = [0.834]
Oct1index = [1.7]
Oct1labels = ['M18 polished']

plt.scatter(Augustindex, Augustalbedo, c='r')
for i in range(len(Augustlabels)):
    plt.annotate(Augustlabels[i],(Augustindex[i],Augustalbedo[i]))
plt.scatter(After3rdindex, After3rdalbedo, c='g')
for i in range(len(After3rdlabels)):
    plt.annotate(After3rdlabels[i],(After3rdindex[i],After3rdalbedo[i]))
plt.scatter(After1stindex, After1stalbedo, c='b')
for i in range(len(After1stlabels)):
    plt.annotate(After1stlabels[i],(After1stindex[i],After1stalbedo[i]))
plt.scatter(Before2ndindex, Before2ndalbedo,c='m')
for i in range(len(Before2ndlabels)):
    plt.annotate(Before2ndlabels[i],(Before2ndindex[i],Before2ndalbedo[i]))
plt.scatter(Oct1index, Oct1albedo, c='c')
for i in range(len(Oct1labels)):
    plt.annotate(Oct1labels[i],(Oct1index[i],Oct1albedo[i]))
    
plt.legend(['August','After 3rd run','After 1st run','Before 2nd run','Oct 1'])
