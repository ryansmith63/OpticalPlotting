# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
# Out:
# Errors (log):  [ 0.00426592  0.01460298  0.01211089]
# Correlation matrix (log):
#  [[ 1.         -0.27184681 -0.19323528]
#  [-0.27184681  1.          0.77111641]
#  [-0.19323528  0.77111641  1.        ]]
# Fit reduced chi^2:  1.6465909648
# Min and max values:
#  [[0.87100846544129606, 0.87847156872402343], [1.1362076345599545, 1.1402443721196232], [0.10985435800149297, 0.11254771317401899]]
# Fit parameters (rho_L, n, gamma): [0.87473205783720975, 1.1382112664971995, 0.11119288095587787]
# Fitting time: 656.1732678413391
# Plotting time: 16.482139825820923
# Reflectance calc time: 15.158320426940918

# %%
# %run Vacuum_data_fitting.py
# Out:
# Errors (log):  [ 0.00666053  0.01890127  0.01622423]
# Correlation matrix (log):
#  [[ 1.         -0.23666762 -0.16146537]
#  [-0.23666762  1.          0.82975626]
#  [-0.16146537  0.82975626  1.        ]]
# Fit reduced chi^2:  1.68976031642
# Min and max values:
#  [[0.79221765101454833, 0.80284143555698562], [1.1248401363004543, 1.1296497448981206], [0.095059410350542176, 0.098194532018441708]]
# Fit parameters (rho_L, n, gamma): [0.79751185333768115, 1.1272222143511128, 0.096614255228307286]
# Fitting time: 708.529527425766
# Plotting time: 13.436888694763184
# Reflectance calc time: 13.874768495559692

# %%
# %run Vacuum_data_fitting.py
#after 3rd run for comparison with Labsphere calibration 400nm
# Out:
# Errors (log):  [ 0.00432286  0.01611532  0.01451238  0.03255764]
# Correlation matrix (log):
#  [[ 1.         -0.30165934 -0.22179466  0.05478132]
#  [-0.30165934  1.          0.78727331 -0.18933855]
#  [-0.22179466  0.78727331  1.         -0.43756125]
#  [ 0.05478132 -0.18933855 -0.43756125  1.        ]]
# Fit reduced chi^2:  1.40102971473
# Min and max values:
#  [[0.86706683013887742, 0.87459575423614699], [1.1446876788776057, 1.1494270224767562], [0.11830753239290595, 0.12179169864761329], [11.575147200188777, 12.353946893440453]]
# Fit parameters (rho_L, n, gamma): [0.87082315557089818, 1.1470382570753397, 0.12003697485749776, 11.958208636534492]
# Fitting time: 781.2515072822571
# Plotting time: 12.53605842590332
# Reflectance calc time: 10.28800654411316

# %%
print(y_total)
# Out:
# [0.81907736954788202, 0.81937771861085462, 0.82034398907540651, 0.82322030994888085]

# %%
# %run Vacuum_data_fitting.py
#after 3rd run for comparison with Labsphere calibration 400nm no correction factor
# Out:
# Errors (log):  [ 0.00427966  0.01497523  0.01204584]
# Correlation matrix (log):
#  [[ 1.         -0.26992629 -0.18941702]
#  [-0.26992629  1.          0.77344508]
#  [-0.18941702  0.77344508  1.        ]]
# Fit reduced chi^2:  1.46142032275
# Min and max values:
#  [[0.93557515577314332, 0.94361740489915269], [1.1479127377326397, 1.1524098020769999], [0.11054340260159062, 0.11323891787319962]]
# Fit parameters (rho_L, n, gamma): [0.93958767583380631, 1.150144434070993, 0.11188304290027852]
# Fitting time: 579.4044616222382
# Plotting time: 12.66179871559143
# Reflectance calc time: 11.699710130691528

# %%
print(y_total)
# Out:
# [0.8852951614398504, 0.8855594937375074, 0.8863526633860354, 0.8884484485454635]

# %%
# %run Vacuum_data_fitting.py
#after 3rd run for comparison with Labsphere calibration 500nm
# Out:
# Errors (log):  [ 0.00666053  0.01890127  0.01622423]
# Correlation matrix (log):
#  [[ 1.         -0.23666762 -0.16146537]
#  [-0.23666762  1.          0.82975626]
#  [-0.16146537  0.82975626  1.        ]]
# Fit reduced chi^2:  1.68976031642
# Min and max values:
#  [[0.79221765101454833, 0.80284143555698562], [1.1248401363004543, 1.1296497448981206], [0.095059410350542176, 0.098194532018441708]]
# Fit parameters (rho_L, n, gamma): [0.79751185333768115, 1.1272222143511128, 0.096614255228307286]
# Fitting time: 688.7128858566284
# Plotting time: 12.512610673904419
# Reflectance calc time: 12.795030117034912

# %%
print(y_total)
# Out:
# [0.7590126851127151, 0.7592280074596598, 0.7600792566311583, 0.7636580396753323]

# %%
# %run Vacuum_data_fitting.py
#after 3rd run for comparison with Labsphere calibration 500nm no correction factor
# Out:
# Errors (log):  [ 0.00670203  0.01952974  0.01612238]
# Correlation matrix (log):
#  [[ 1.         -0.24051946 -0.16325468]
#  [-0.24051946  1.          0.83279571]
#  [-0.16325468  0.83279571  1.        ]]
# Fit reduced chi^2:  1.54540854605
# Min and max values:
#  [[0.84950728862675118, 0.86097078589857146], [1.1368247609022326, 1.1422748107970386], [0.096609616289591665, 0.099775538386185567]]
# Fit parameters (rho_L, n, gamma): [0.85521983016972813, 1.1395231771775398, 0.098179817063268213]
# Fitting time: 696.1528532505035
# Plotting time: 12.885816097259521
# Reflectance calc time: 14.089759588241577

# %%
print(y_total)
# Out:
# [0.8113932028930666, 0.8116254123664679, 0.8124689189410869, 0.8156198084657102]
