# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
#solid angle of 1.7
# Out:
# Errors (log):  [ 0.00382114  0.02301845  0.0173724 ]
# Correlation matrix (log):
#  [[ 1.         -0.27586609 -0.21525557]
#  [-0.27586609  1.          0.72583364]
#  [-0.21525557  0.72583364  1.        ]]
# Fit reduced chi^2:  0.69471354204
# Min and max values:
#  [[1.1304904534299374, 1.1391630658650183], [1.173367736331087, 1.1815356172862876], [0.17491950760341879, 0.1811038654009286]]
# Fit parameters (rho_L, n, gamma): [1.1348184748497807, 1.1774046759033996, 0.17798482789554357]
# Fitting time: 517.635500907898
# Plotting time: 14.068606853485107
# Reflectance calc time: 7.466584205627441

# %%
print(y_total)
# Out:
# [1.0371195557845465, 1.0376593192990506, 1.0381387115799015, 1.0342203855722005]

# %%
# %run Vacuum_data_fitting.py
#should be same as above, checking Scott's changes didn't affect this too much
# Out:
# Errors (log):  [ 0.00378328  0.02481925  0.01416306]
# Correlation matrix (log):
#  [[ 1.         -0.26196907 -0.21971406]
#  [-0.26196907  1.          0.6531173 ]
#  [-0.21971406  0.6531173   1.        ]]
# Fit reduced chi^2:  0.832887572824
# Min and max values:
#  [[1.1294968342142135, 1.1380756569660395], [1.1790814913431436, 1.1881951491683886], [0.20792058085339557, 0.21389437325069691]]
# Fit parameters (rho_L, n, gamma): [1.1337781315757518, 1.1835817746308723, 0.21088632560590054]
# Fitting time: 508.5104327201843
# Plotting time: 12.86603832244873
# Reflectance calc time: 6.798318147659302

# %%
# %run Vacuum_data_fitting.py
# Out:
# Errors (log):  [ 0.00380215  0.02545156  0.01479549]
# Correlation matrix (log):
#  [[ 1.         -0.28782278 -0.21904879]
#  [-0.28782278  1.          0.83060577]
#  [-0.21904879  0.83060577  1.        ]]
# Fit reduced chi^2:  0.690575864262
# Min and max values:
#  [[1.0020645039728224, 1.0097135588042956], [1.1256632417324521, 1.1322254946108101], [0.17276328501647181, 0.1779519102097743]]
# Fit parameters (rho_L, n, gamma): [1.0058817606746131, 1.1289026155377435, 0.17533840589784327]
# Fitting time: 611.8025186061859
# Plotting time: 12.700559616088867
# Reflectance calc time: 6.136847257614136

# %%
print(y_total)
# Out:
# [0.9296158561895432, 0.9299390669549982, 0.9306834193267758, 0.9312689470731512]

# %%
# %run Vacuum_data_fitting.py
# Out:
# Errors (log):  [ 0.00380215  0.02545156  0.01479549]
# Correlation matrix (log):
#  [[ 1.         -0.28782278 -0.21904879]
#  [-0.28782278  1.          0.83060577]
#  [-0.21904879  0.83060577  1.        ]]
# Fit reduced chi^2:  0.690575864262
# Min and max values:
#  [[1.0020645039728224, 1.0097135588042956], [1.1256632417324521, 1.1322254946108101], [0.17276328501647181, 0.1779519102097743]]
# Fit parameters (rho_L, n, gamma): [1.0058817606746131, 1.1289026155377435, 0.17533840589784327]
# Fitting time: 624.7644338607788
# Plotting time: 12.247085332870483
# Reflectance calc time: 6.6531126499176025
