# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
#August data
# Out:
# Errors (log):  [ 0.00832443  0.01573315  0.00957928]
# Correlation matrix (log):
#  [[ 1.         -0.39829053 -0.27408613]
#  [-0.39829053  1.          0.82115442]
#  [-0.27408613  0.82115442  1.        ]]
# Fit reduced chi^2:  12.1250876718
# Min and max values:
#  [[0.68637880124934691, 0.69790188647756857], [1.9021922880988695, 1.9310322971303471], [0.15743806054862217, 0.16048342603754404]]
# Fit parameters (rho_L, n, gamma): [0.69211636321512537, 1.9164988589419927, 0.15895345024738905]
# Fitting time: 265.12548756599426
# Plotting time: 8.182494163513184
# Reflectance calc time: 8.801809072494507

# %%
# %run Vacuum_data_fitting.py
#2/20/19 data
# Out:
# Errors (log):  [ 0.00490988  0.01268777  0.00725082]
# Correlation matrix (log):
#  [[ 1.         -0.24641042 -0.12441628]
#  [-0.24641042  1.          0.76296477]
#  [-0.12441628  0.76296477  1.        ]]
# Fit reduced chi^2:  5.63815036293
# Min and max values:
#  [[0.90349937662316393, 0.91241522498744765], [1.6060916307853117, 1.6216683289871265], [0.14464030964106817, 0.14675311531332411]]
# Fit parameters (rho_L, n, gamma): [0.90794635689430625, 1.6138305721641659, 0.14569288259798616]
# Fitting time: 318.1328332424164
# Plotting time: 12.008827447891235
# Reflectance calc time: 9.828377485275269

# %%
# %run Vacuum_data_fitting.py
#2/20/19 data
# Out:
# Errors (log):  [ 0.00487024  0.01275172  0.00758162]
# Correlation matrix (log):
#  [[ 1.         -0.24277977 -0.12978801]
#  [-0.24277977  1.          0.77836881]
#  [-0.12978801  0.77836881  1.        ]]
# Fit reduced chi^2:  5.15060315601
# Min and max values:
#  [[0.8999736937416154, 0.90878271058425852], [1.5808299297024149, 1.5958335957643999], [0.13913839022697153, 0.14126425574469334]]
# Fit parameters (rho_L, n, gamma): [0.90436747666699768, 1.5882839327588112, 0.14019729362911343]
# Fitting time: 326.2320246696472
# Plotting time: 12.060027837753296
# Reflectance calc time: 9.958754301071167

# %%
# %run Vacuum_data_fitting.py
#2/20/19 data
# Out:
# Errors (log):  [ 0.00490908  0.01289669  0.00759658]
# Correlation matrix (log):
#  [[ 1.         -0.24584352 -0.13063137]
#  [-0.24584352  1.          0.78185626]
#  [-0.13063137  0.78185626  1.        ]]
# Fit reduced chi^2:  5.07425291844
# Min and max values:
#  [[0.90194516017267967, 0.9108442098484576], [1.6011323629770633, 1.6168392894376296], [0.14148357715354351, 0.14364957300614606]]
# Fit parameters (rho_L, n, gamma): [0.90638376350424821, 1.6089351850868323, 0.14256246155804356]
# Fitting time: 400.16231298446655
# Plotting time: 13.157302379608154
# Reflectance calc time: 11.122689962387085

# %%
# %run Vacuum_data_fitting.py
#2/20/19 data
# Out:
# Errors (log):  [ 0.00490421  0.01291022  0.00757007]
# Correlation matrix (log):
#  [[ 1.         -0.23997164 -0.12499738]
#  [-0.23997164  1.          0.78126188]
#  [-0.12499738  0.78126188  1.        ]]
# Fit reduced chi^2:  4.75403249079
# Min and max values:
#  [[0.9085543382484822, 0.91750967374837], [1.6097734014057745, 1.6257230417004385], [0.14223884269577183, 0.14440874355864686]]
# Fit parameters (rho_L, n, gamma): [0.91302102630171178, 1.6176967439412673, 0.14331968657142821]
# Fitting time: 401.69879388809204
# Plotting time: 12.566869974136353
# Reflectance calc time: 10.723767042160034

# %%
# %run Vacuum_data_fitting.py
#2/20/19 data
# Out:
# Errors (log):  [ 0.00496066  0.01267107  0.00727694]
# Correlation matrix (log):
#  [[ 1.         -0.24765835 -0.13134167]
#  [-0.24765835  1.          0.77443408]
#  [-0.13134167  0.77443408  1.        ]]
# Fit reduced chi^2:  4.12311183668
# Min and max values:
#  [[0.88965458163032995, 0.89852505146868678], [1.6287127678244429, 1.6448492937671624], [0.14487519763241649, 0.14699911080049705]]
# Fit parameters (rho_L, n, gamma): [0.89407881573647929, 1.6367299147315051, 0.14593329033846766]
# Fitting time: 348.2980179786682
# Plotting time: 12.854453325271606
# Reflectance calc time: 10.363962650299072

# %%
# %run Vacuum_data_fitting.py
#2/20/19 data
# Out:
# Errors (log):  [ 0.00505632  0.0128313   0.00728016]
# Correlation matrix (log):
#  [[ 1.         -0.26219839 -0.14114015]
#  [-0.26219839  1.          0.77961595]
#  [-0.14114015  0.77961595  1.        ]]
# Fit reduced chi^2:  3.92551336297
# Min and max values:
#  [[0.88786968616042439, 0.89689395078052403], [1.6654815763166426, 1.6827805852475282], [0.14865050862618515, 0.15083074211277178]]
# Fit parameters (rho_L, n, gamma): [0.89237041109546378, 1.6740755893436023, 0.14973665727379015]
# Fitting time: 407.85378551483154
# Plotting time: 12.873286962509155
# Reflectance calc time: 9.994641542434692
