# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
#August data
# Out:
# Errors (log):  [0.00624906 0.0164727  0.01391519 0.01141649]
# Correlation matrix (log):
#  [[ 1.         -0.33245696 -0.20885233 -0.1791671 ]
#  [-0.33245696  1.          0.66140323  0.49166555]
#  [-0.20885233  0.66140323  1.          0.11493975]
#  [-0.1791671   0.49166555  0.11493975  1.        ]]
# Fit reduced chi^2:  6.213287983293716
# Min and max values:
#  [[0.9783896295864025, 0.9906943860747089], [1.5767307948245461, 1.596047884607752], [0.14068821288203542, 0.14465861292755003], [3.6639248036691034, 3.7485455573164215]]
# Fit parameters (rho_L, n, gamma): [0.9845227846144359, 1.5863097903355514, 0.14265960090639226, 3.7059936650155327]
# Fitting time: 302.214732170105
# Plotting time: 7.435074090957642
# Reflectance calc time: 8.960746765136719

# %%
# %run Vacuum_data_fitting.py
#October 1 data
# Out:
# Errors (log):  [0.00661109 0.01010588 0.01239674 0.01217512]
# Correlation matrix (log):
#  [[ 1.         -0.23089585 -0.26340875 -0.0235612 ]
#  [-0.23089585  1.          0.47990758  0.17407652]
#  [-0.26340875  0.47990758  1.         -0.32394117]
#  [-0.0235612   0.17407652 -0.32394117  1.        ]]
# Fit reduced chi^2:  3.0681601056569523
# Min and max values:
#  [[0.828616845296209, 0.8396457259628528], [1.6929766827183799, 1.7071254652918455], [0.09057467090643723, 0.09284840254937515], [3.1397561184732035, 3.217148353963799]]
# Fit parameters (rho_L, n, gamma): [0.8341130574531155, 1.7000153278347794, 0.09170449010325538, 3.1782166742363294]
# Fitting time: 245.6958634853363
# Plotting time: 6.70023512840271
# Reflectance calc time: 12.521361112594604

# %%
# %run Vacuum_data_fitting.py
#2/20/19 data
# Out:
# Errors (log):  [ 0.00477668  0.00808183  0.0115404   0.01196395]
# Correlation matrix (log):
#  [[ 1.         -0.21293759 -0.25069733  0.06599125]
#  [-0.21293759  1.          0.49693054  0.00244256]
#  [-0.25069733  0.49693054  1.         -0.55229729]
#  [ 0.06599125  0.00244256 -0.55229729  1.        ]]
# Fit reduced chi^2:  4.01564286875
# Min and max values:
#  [[0.90001141458162182, 0.90865074785284028], [1.5400387849649082, 1.5488387193410826], [0.079530398156514207, 0.081387370372271714], [3.4502969733368869, 3.533850976702233]]
# Fit parameters (rho_L, n, gamma): [0.9043207644059067, 1.5444209723501241, 0.080453526775514678, 3.4918240690417548]
# Fitting time: 460.7698349952698
# Plotting time: 15.39142918586731
# Reflectance calc time: 18.666903018951416

# %%
# %run Vacuum_data_fitting.py
#2/20/19 data
# Out:
# Errors (log):  [ 0.00470718  0.00793732  0.01185073  0.01250398]
# Correlation matrix (log):
#  [[ 1.         -0.19220946 -0.23947728  0.07775588]
#  [-0.19220946  1.          0.48296485 -0.02150764]
#  [-0.23947728  0.48296485  1.         -0.59395342]
#  [ 0.07775588 -0.02150764 -0.59395342  1.        ]]
# Fit reduced chi^2:  3.78438765031
# Min and max values:
#  [[0.90451445102342742, 0.9130700941173806], [1.5273956425580124, 1.5358346608675988], [0.076361781961211739, 0.07819328637199062], [3.3790356626146472, 3.4646039552554124]]
# Fit parameters (rho_L, n, gamma): [0.9087822043407825, 1.5315984060107046, 0.077272108064737929, 3.4215523263050942]
# Fitting time: 427.46685767173767
# Plotting time: 12.666637897491455
# Reflectance calc time: 19.132116079330444

# %%
# %run Vacuum_data_fitting.py
#2/20/19 data
# Out:
# Errors (log):  [ 0.12451151  0.00527981  0.00705832  0.00936851]
# Correlation matrix (log):
#  [[ 1.         -0.43829187 -0.42513516  0.07952851]
#  [-0.43829187  1.          0.27937416  0.03493948]
#  [-0.42513516  0.27937416  1.         -0.49783405]
#  [ 0.07952851  0.03493948 -0.49783405  1.        ]]
# Fit reduced chi^2:  9.04174634359
# Min and max values:
#  [[0.014427232130630477, 0.018506843164008246], [1.8704237672122344, 1.8796638126645884], [0.091228107156641591, 0.092525074240094735], [3.7915185972171157, 3.8632301232133361]]
# Fit parameters (rho_L, n, gamma): [0.016340211820301435, 1.8750315935437922, 0.091874302105929381, 3.8272064038267826]
# Fitting time: 612.9099171161652
# Plotting time: 13.630361318588257
# Reflectance calc time: 18.684675455093384
