# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
# Out:
# Errors (log):  [ 0.00541176  0.01055543  0.00664977]
# Correlation matrix (log):
#  [[ 1.         -0.39803812 -0.25844353]
#  [-0.39803812  1.          0.78424139]
#  [-0.25844353  0.78424139  1.        ]]
# Fit reduced chi^2:  8.17398400485
# Min and max values:
#  [[0.66837795260745425, 0.67565145073080457], [1.6649410364578143, 1.6791277374104596], [0.14373702829826576, 0.1456614345130175]]
# Fit parameters (rho_L, n, gamma): [0.67200486108041757, 1.6719969505890346, 0.14469603220048427]
# Fitting time: 485.21706366539
# Plotting time: 8.049773454666138
# Reflectance calc time: 10.076758861541748

# %%
# %run Vacuum_data_fitting.py
#After 1st run
# Out:
# Errors (log):  [ 0.00510181  0.01400858  0.00859335]
# Correlation matrix (log):
#  [[ 1.         -0.3034967  -0.18381531]
#  [-0.3034967   1.          0.73300028]
#  [-0.18381531  0.73300028  1.        ]]
# Fit reduced chi^2:  12.3706771099
# Min and max values:
#  [[0.65709884800739959, 0.6638379606408088], [1.2568220274986808, 1.2641191993746941], [0.13355625149304101, 0.13587148202582058]]
# Fit parameters (rho_L, n, gamma): [0.66045980892152467, 1.2604450580923685, 0.13470889289194196]
# Fitting time: 604.4899625778198
# Plotting time: 12.230088710784912
# Reflectance calc time: 9.67435336112976

# %%
# %run Vacuum_data_fitting.py
#After 1st run
# Out:
# Errors (log):  [0.00556181 0.01239948 0.00891368]
# Correlation matrix (log):
#  [[ 1.         -0.36553759 -0.23226849]
#  [-0.36553759  1.          0.77275374]
#  [-0.23226849  0.77275374  1.        ]]
# Fit reduced chi^2:  4.701370548851241
# Min and max values:
#  [[0.6304261021109174, 0.6374778739220957], [1.3112130972931086, 1.319027348902975], [0.11515130616330822, 0.11722255682670475]]
# Fit parameters (rho_L, n, gamma): [0.6339421828831566, 1.3150960002496128, 0.1161823159108032]
# Fitting time: 414.3871817588806
# Plotting time: 12.155064344406128
# Reflectance calc time: 11.149174451828003

# %%
# %run Vacuum_data_fitting.py
#After 1st run
# Out:
# Errors (log):  [0.00543053 0.01240401 0.00935998]
# Correlation matrix (log):
#  [[ 1.         -0.34879935 -0.21874821]
#  [-0.34879935  1.          0.77107364]
#  [-0.21874821  0.77107364  1.        ]]
# Fit reduced chi^2:  7.440860659546714
# Min and max values:
#  [[0.6272048182216986, 0.6340540540009387], [1.2698669706661831, 1.2766455683551086], [0.10957458324267927, 0.11164513600119207]]
# Fit parameters (rho_L, n, gamma): [0.6306201373904816, 1.273235249336936, 0.11060501457168598]
# Fitting time: 389.1191873550415
# Plotting time: 12.376881122589111
# Reflectance calc time: 11.379324913024902

# %%
# %run Vacuum_data_fitting.py
#After 1st run
# Out:
# Errors (log):  [0.00549794 0.0123218  0.0086341 ]
# Correlation matrix (log):
#  [[ 1.         -0.34854411 -0.21927908]
#  [-0.34854411  1.          0.76740662]
#  [-0.21927908  0.76740662  1.        ]]
# Fit reduced chi^2:  3.303705826863827
# Min and max values:
#  [[0.6439156001401404, 0.6510350874372371], [1.3262627944477363, 1.3344029741222716], [0.11681813612788033, 0.11885289239345988]]
# Fit parameters (rho_L, n, gamma): [0.6474655581877984, 1.3303078091852605, 0.11783112221654986]
# Fitting time: 265.5125494003296
# Plotting time: 9.40046238899231
# Reflectance calc time: 7.997164487838745

# %%
# %run Vacuum_data_fitting.py
#After 1st run
# Out:
# Errors (log):  [0.00556341 0.01307316 0.01003348 0.03702629]
# Correlation matrix (log):
#  [[ 1.         -0.36304415 -0.23065434  0.05149474]
#  [-0.36304415  1.          0.78008452 -0.22564506]
#  [-0.23065434  0.78008452  1.         -0.44716719]
#  [ 0.05149474 -0.22564506 -0.44716719  1.        ]]
# Fit reduced chi^2:  3.162897868943277
# Min and max values:
#  [[0.6418870703178547, 0.6490691108847406], [1.3350463171973252, 1.3439220746390186], [0.12036750146565331, 0.12280731000149192], [12.057159461455974, 12.98391404657049]]
# Fit parameters (rho_L, n, gamma): [0.6454681014733579, 1.33945518777987, 0.12158128584036904, 12.511959162870479]
# Fitting time: 454.3818554878235
# Plotting time: 9.297170162200928
# Reflectance calc time: 8.511986494064331

# %%
# %run Vacuum_data_fitting.py
#After 1st run no mirror correction
# Out:
# Errors (log):  [0.00577141 0.01288381 0.00862836 0.02880794]
# Correlation matrix (log):
#  [[ 1.         -0.38454024 -0.25234323  0.044662  ]
#  [-0.38454024  1.          0.76667021 -0.16831405]
#  [-0.25234323  0.76667021  1.         -0.37446246]
#  [ 0.044662   -0.16831405 -0.37446246  1.        ]]
# Fit reduced chi^2:  3.280245157537625
# Min and max values:
#  [[0.5750906354457402, 0.581767258794073], [1.3638435080012967, 1.3733407270131213], [0.1370998211915461, 0.1394862461953532], [12.817601945039309, 13.57778847881697]]
# Fit parameters (rho_L, n, gamma): [0.5784193137693535, 1.368561527829762, 0.13828788599173428, 13.192220738579866]
# Fitting time: 465.88338708877563
# Plotting time: 10.717143535614014
# Reflectance calc time: 9.737542152404785

# %%
# %run Vacuum_data_fitting.py
#After 1st run no mirror correction, adjusted 52 and 60 further
# Out:
# Errors (log):  [0.00621908 0.01304538 0.00823231 0.02720947]
# Correlation matrix (log):
#  [[ 1.         -0.4417587  -0.29022212  0.04755156]
#  [-0.4417587   1.          0.77164062 -0.15878168]
#  [-0.29022212  0.77164062  1.         -0.35332785]
#  [ 0.04755156 -0.15878168 -0.35332785  1.        ]]
# Fit reduced chi^2:  1.8570384210343123
# Min and max values:
#  [[0.5616724301293978, 0.5687022293040329], [1.4280574463905304, 1.4393727653352268], [0.14598066754896066, 0.1484040801837164], [12.946950767946781, 13.67103331499939]]
# Fit parameters (rho_L, n, gamma): [0.5651764000320627, 1.4336782032140225, 0.14718738632168316, 13.30406686980554]
# Fitting time: 459.55804681777954
# Plotting time: 9.510258913040161
# Reflectance calc time: 7.042865514755249
