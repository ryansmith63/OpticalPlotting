# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
#August data
# Out:
# Errors (log):  [0.00622457 0.01958466 0.01055833]
# Correlation matrix (log):
#  [[ 1.         -0.29442136 -0.12112941]
#  [-0.29442136  1.          0.77576733]
#  [-0.12112941  0.77576733  1.        ]]
# Fit reduced chi^2:  11.19583019170702
# Min and max values:
#  [[0.9806839122248782, 0.9929689025887045], [1.6037491792079452, 1.6278668739611897], [0.16218338739870333, 0.16564457543572048]]
# Fit parameters (rho_L, n, gamma): [0.9868072902590124, 1.6156899461627798, 0.16390484540850275]
# Fitting time: 217.63636922836304
# Plotting time: 6.742304801940918
# Reflectance calc time: 7.231787443161011

# %%
# %run Vacuum_data_fitting.py
#After 1st run
# Out:
# Errors (log):  [0.00521363 0.01561016 0.00866967]
# Correlation matrix (log):
#  [[ 1.         -0.36112148 -0.21004633]
#  [-0.36112148  1.          0.766875  ]
#  [-0.21004633  0.766875    1.        ]]
# Fit reduced chi^2:  8.037046157986016
# Min and max values:
#  [[0.7376402251819559, 0.7453720308749505], [1.3148614066361868, 1.3248465372643565], [0.14596354520743654, 0.1485165266267625]]
# Fit parameters (rho_L, n, gamma): [0.7414960503596295, 1.3198150053764672, 0.14723450257442003]
# Fitting time: 479.5473737716675
# Plotting time: 12.255877494812012
# Reflectance calc time: 8.237743139266968

# %%
# %run Vacuum_data_fitting.py
#After 1st run
# Out:
# Errors (log):  [0.00522957 0.01472913 0.00978645]
# Correlation matrix (log):
#  [[ 1.         -0.35107874 -0.21549025]
#  [-0.35107874  1.          0.80127715]
#  [-0.21549025  0.80127715  1.        ]]
# Fit reduced chi^2:  5.481925503875636
# Min and max values:
#  [[0.7377947230389387, 0.745551919124855], [1.3048500545017474, 1.3139639879040819], [0.12678263133266923, 0.1292885786918732]]
# Fit parameters (rho_L, n, gamma): [0.7416631794028011, 1.309373461732168, 0.1280294739808633]
# Fitting time: 355.1582691669464
# Plotting time: 12.424253225326538
# Reflectance calc time: 8.54494309425354

# %%
# %run Vacuum_data_fitting.py
#After 1st run
# Out:
# Errors (log):  [0.00526702 0.01609908 0.01130098 0.04129143]
# Correlation matrix (log):
#  [[ 1.         -0.36001962 -0.22183485  0.03974272]
#  [-0.36001962  1.          0.81248081 -0.22507871]
#  [-0.22183485  0.81248081  1.         -0.4396019 ]
#  [ 0.03974272 -0.22507871 -0.4396019   1.        ]]
# Fit reduced chi^2:  4.583515159186224
# Min and max values:
#  [[0.7449331780180436, 0.7528218036357339], [1.3231412832520772, 1.3337151519296475], [0.133440081066219, 0.1364904303571506], [13.012849605501817, 14.133108506471496]]
# Fit parameters (rho_L, n, gamma): [0.7488671034727342, 1.3283856611291185, 0.1349566378197875, 13.561416425025522]
# Fitting time: 441.6681110858917
# Plotting time: 10.075520515441895
# Reflectance calc time: 8.061726331710815

# %%
# %run Vacuum_data_fitting.py
#After 1st run no mirror correction
# Out:
# Errors (log):  [0.00538017 0.01572496 0.00945385 0.0394611 ]
# Correlation matrix (log):
#  [[ 1.         -0.3782655  -0.23832556  0.03632201]
#  [-0.3782655   1.          0.79939667 -0.17623394]
#  [-0.23832556  0.79939667  1.         -0.3683649 ]
#  [ 0.03632201 -0.17623394 -0.3683649   1.        ]]
# Fit reduced chi^2:  1.6805249446880817
# Min and max values:
#  [[0.6901707014539769, 0.6976372677765774], [1.3597035669828512, 1.3711959870351638], [0.1508537298174786, 0.1537331631269038], [14.620556654752228, 15.821198728114146]]
# Fit parameters (rho_L, n, gamma): [0.6938939417964364, 1.3654045984744425, 0.15228664108953324, 15.209034563393127]
# Fitting time: 482.3922507762909
# Plotting time: 9.270944118499756
# Reflectance calc time: 6.214420318603516

# %%
mirrors = [[30,"First Xe Run Measurements/Mirror alignment checks 10-29/2018_10_29__09_33_56.txt"],
           [45,"First Xe Run Measurements/Mirror alignment checks 10-29/2018_10_29__09_31_00.txt"],
           [60,"First Xe Run Measurements/Mirror alignment checks 10-29/2018_10_29__09_25_03.txt"],
           [75,"First Xe Run Measurements/Mirror alignment checks 10-29/2018_10_29__09_45_18.txt"]]

# %%
from file_reader import incident_power_factor_list
print(incident_power_factor_list(mirrors))
# Out:
# [[30, 1], [45, 1], [60, 1], [75, 0.6945270953324314]]
