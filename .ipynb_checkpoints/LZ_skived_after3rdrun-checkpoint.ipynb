# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
#August data, no spike
# Out:
# Errors (log):  [ 0.00409756  0.00628307  0.00480366]
# Correlation matrix (log):
#  [[ 1.        -0.2701387 -0.2361951]
#  [-0.2701387  1.         0.6760354]
#  [-0.2361951  0.6760354  1.       ]]
# Fit reduced chi^2:  23.2787903681
# Min and max values:
#  [[0.76816931453725679, 0.77449041612040581], [1.8649841617531231, 1.8759222598011183], [0.10732371950260143, 0.10835978237822579]]
# Fit parameters (rho_L, n, gamma): [0.77132339006858008, 1.8704360296167499, 0.10784050671859641]
# Fitting time: 180.49246835708618
# Plotting time: 6.727294921875
# Reflectance calc time: 10.437887907028198

# %%
# %run Vacuum_data_fitting.py
#After 1st run [20,36,43,52,63,71]
# Out:
# Errors (log):  [ 0.00295332  0.00776329  0.00577287]
# Correlation matrix (log):
#  [[ 1.         -0.32155771 -0.19464597]
#  [-0.32155771  1.          0.74733361]
#  [-0.19464597  0.74733361  1.        ]]
# Fit reduced chi^2:  49.0174322113
# Min and max values:
#  [[0.87296269917359015, 0.87813423786523415], [1.398030914627594, 1.4042591982325052], [0.11212501586515673, 0.11342708488190904]]
# Fit parameters (rho_L, n, gamma): [0.87554465021698247, 1.4011329685018445, 0.11277417120920255]
# Fitting time: 434.1692056655884
# Plotting time: 11.281057596206665
# Reflectance calc time: 9.531556844711304

# %%
# %run Vacuum_data_fitting.py
#After 1st run [25,40,48,55,64,72]

# %%
# %run Vacuum_data_fitting.py
#After 3rd run
# Out:
# Errors (log):  [ 0.00501531  0.00626409  0.00363323]
# Correlation matrix (log):
#  [[ 1.         -0.35939971 -0.24458811]
#  [-0.35939971  1.          0.62895183]
#  [-0.24458811  0.62895183  1.        ]]
# Fit reduced chi^2:  42.7581291389
# Min and max values:
#  [[0.54249316812432047, 0.5479620902020067], [1.6079541116750522, 1.6156185804517478], [0.1253179446645212, 0.12623187896822616]]
# Fit parameters (rho_L, n, gamma): [0.54522077209669051, 1.6117743433727822, 0.12577408168394116]
# Fitting time: 413.28159260749817
# Plotting time: 10.749092817306519
# Reflectance calc time: 7.677027463912964

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, with specular spike
# Out:
# Errors (log):  [ 0.00494556  0.00683626  0.00493235  0.00778487]
# Correlation matrix (log):
#  [[ 1.         -0.37540756 -0.27721387  0.03517329]
#  [-0.37540756  1.          0.68880684 -0.08659987]
#  [-0.27721387  0.68880684  1.         -0.35877632]
#  [ 0.03517329 -0.08659987 -0.35877632  1.        ]]
# Fit reduced chi^2:  39.7588856046
# Min and max values:
#  [[0.54128953041624983, 0.54667006095419202], [1.5551488990000251, 1.5627913100284014], [0.12288421801077951, 0.1241024324254317], [7.9515419478717568, 8.0763142115718907]]
# Fit parameters (rho_L, n, gamma): [0.543973143258486, 1.5589570431876216, 0.12349182305656832, 8.0136852469701285]
# Fitting time: 572.5630495548248
# Plotting time: 10.925851106643677
# Reflectance calc time: 9.065544843673706

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, no specular spike, omitting 75
# Out:
# Errors (log):  [ 0.0048522   0.00729726  0.00544271]
# Correlation matrix (log):
#  [[ 1.         -0.34550922 -0.2420052 ]
#  [-0.34550922  1.          0.77369316]
#  [-0.2420052   0.77369316  1.        ]]
# Fit reduced chi^2:  12.27038991
# Min and max values:
#  [[0.67250734487790975, 0.67906538799972593], [1.5906888300140571, 1.5993728609684332], [0.10664028221705699, 0.1078074473929555]]
# Fit parameters (rho_L, n, gamma): [0.67577841122825411, 1.5950150031617876, 0.10722227667367122]
# Fitting time: 287.9581186771393
# Plotting time: 9.303582668304443
# Reflectance calc time: 10.273412466049194

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, no specular spike, omitting 75, changed 30 to 28
# Out:
# Errors (log):  [ 0.0048306   0.00728352  0.00538455]
# Correlation matrix (log):
#  [[ 1.         -0.33711946 -0.23594125]
#  [-0.33711946  1.          0.77197121]
#  [-0.23594125  0.77197121  1.        ]]
# Fit reduced chi^2:  11.0568754044
# Min and max values:
#  [[0.6822835408129907, 0.68890716977312427], [1.6032753164415652, 1.6121275700343316], [0.10691539514194548, 0.10807299896016309]]
# Fit parameters (rho_L, n, gamma): [0.68558735627508716, 1.6076853244196934, 0.10749263876192128]
# Fitting time: 286.76340889930725
# Plotting time: 8.191923141479492
# Reflectance calc time: 10.666857481002808

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, no specular spike, omitting 75, changed 30 to 28, mirror-corrected
# Out:
# Errors (log):  [ 0.00481956  0.00733133  0.00545658]
# Correlation matrix (log):
#  [[ 1.         -0.33840051 -0.23611108]
#  [-0.33840051  1.          0.77560414]
#  [-0.23611108  0.77560414  1.        ]]
# Fit reduced chi^2:  9.7078724887
# Min and max values:
#  [[0.69629200947335346, 0.70303609794517641], [1.6054995118720585, 1.6144431555080356], [0.10624018803329272, 0.10740595455697685]]
# Fit parameters (rho_L, n, gamma): [0.69965592784636088, 1.6099549415598196, 0.10682148102338083]
# Fitting time: 271.462744474411
# Plotting time: 8.693197965621948
# Reflectance calc time: 10.843315601348877

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, with specular spike, changed 30 to 28, mirror-corrected
# Out:
# Errors (log):  [ 0.00510478  0.00827698  0.00707403  0.01289707]
# Correlation matrix (log):
#  [[ 1.         -0.39502049 -0.28396822  0.07286586]
#  [-0.39502049  1.          0.79324343 -0.22147508]
#  [-0.28396822  0.79324343  1.         -0.50672136]
#  [ 0.07286586 -0.22147508 -0.50672136  1.        ]]
# Fit reduced chi^2:  7.87627764449
# Min and max values:
#  [[0.68394562657161462, 0.69096417259607257], [1.6607805262133311, 1.6718100974497512], [0.11785253974222347, 0.11953177565380761], [7.9881690604270652, 8.1968974354790642]]
# Fit parameters (rho_L, n, gamma): [0.68744594257640224, 1.6662724890825644, 0.11868918796882427, 8.0918602611258557]
# Fitting time: 315.05260848999023
# Plotting time: 8.464218139648438
# Reflectance calc time: 9.067725658416748

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, with specular spike, mirror-corrected, 75 added back
# Out:
# Errors (log):  [ 0.01411456  0.01810458  0.01312216  0.02100281]
# Correlation matrix (log):
#  [[ 1.         -0.39728323 -0.25831196  0.04175113]
#  [-0.39728323  1.          0.81606411 -0.21222013]
#  [-0.25831196  0.81606411  1.         -0.46687755]
#  [ 0.04175113 -0.21222013 -0.46687755  1.        ]]
# Fit reduced chi^2:  1.83835778396
# Min and max values:
#  [[0.67159456134003537, 0.6908232061278794], [1.6147274444463644, 1.6373941077392564], [0.11135264999491422, 0.11431371020880883], [8.3862463950465713, 8.7460191437318517]]
# Fit parameters (rho_L, n, gamma): [0.68114103391512837, 1.6259581862678401, 0.11282346636450034, 8.5642437795248174]
# Fitting time: 450.81907296180725
# Plotting time: 9.835583448410034
# Reflectance calc time: 9.600286483764648

# %%
# %run Vacuum_data_fitting.py

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, with specular spike, mirror-corrected, 75 added back, bounded
# Out:
# Errors (log):  [ 0.01348391  0.01809274  0.01345565  0.0231849 ]
# Correlation matrix (log):
#  [[ 1.         -0.37723644 -0.24563022  0.04830836]
#  [-0.37723644  1.          0.81638225 -0.23915065]
#  [-0.24563022  0.81638225  1.         -0.49011369]
#  [ 0.04830836 -0.23915065 -0.49011369  1.        ]]
# Fit reduced chi^2:  1.86855457613
# Min and max values:
#  [[0.68707815617567658, 0.70585925644377778], [1.5696005715866304, 1.5905892949913181], [0.10624459235716564, 0.10914259255057886], [8.553687591582996, 8.95966014664765]]
# Fit parameters (rho_L, n, gamma): [0.69640539661674428, 1.5800000000000001, 0.10768384398014622, 8.7543208657885447]
# Fitting time: 472.36009430885315
# Plotting time: 9.83075761795044
# Reflectance calc time: 10.196574926376343

# %%
# %run Vacuum_data_fitting.py
#After 3rd run, with specular spike, mirror-corrected, 75 added back, unbounded Lorentz
# Out:
# Errors (log):  [ 0.01628413  0.02244218  0.02309199  0.02299136]
# Correlation matrix (log):
#  [[ 1.         -0.44274626 -0.30069403  0.08494242]
#  [-0.44274626  1.          0.8622986  -0.35197185]
#  [-0.30069403  0.8622986   1.         -0.58562511]
#  [ 0.08494242 -0.35197185 -0.58562511  1.        ]]
# Fit reduced chi^2:  2.8704355434
# Min and max values:
#  [[0.64981857076812077, 0.6713304346738842], [1.8585000275446999, 1.8979111140075644], [0.10756562038512084, 0.11264993223096616], [9.0176079476300597, 9.4419433847291643]]
# Fit parameters (rho_L, n, gamma): [0.66048692914616003, 1.8779844623387056, 0.11007842589156921, 9.2273367613416379]
# Fitting time: 570.5794410705566
# Plotting time: 9.374587059020996
# Reflectance calc time: 13.189939498901367

# %%
# %run Vacuum_data_fitting.py
#files for 178nm after 3rd xenon run vacuum data were no longer in Vacuum_data_fitting.py, checking fits from above,
#all angles unshifted except 30->28, solid angle 2.15, background and mirror correction from January 14
# Out:
# Errors (log):  [0.00887568 0.01781223 0.01208372 0.01847609]
# Correlation matrix (log):
#  [[ 1.         -0.26890101 -0.14373432 -0.00234898]
#  [-0.26890101  1.          0.78496612 -0.12273714]
#  [-0.14373432  0.78496612  1.         -0.40276532]
#  [-0.00234898 -0.12273714 -0.40276532  1.        ]]
# Fit reduced chi^2:  1.039596579404221
# Min and max values:
#  [[1.0807858816099822, 1.1001425916323815], [1.6534344833859462, 1.6771323428197071], [0.11693526869386418, 0.11979571996026808], [8.206537918734735, 8.51545997939699]]
# Fit parameters (rho_L, n, gamma): [1.0904212859230573, 1.6651778879475105, 0.11835685321065637, 8.35957207136762]
# Fitting time: 396.02661395072937
# Plotting time: 10.816033601760864
# Reflectance calc time: 10.26847529411316

# %%
# %run Vacuum_data_fitting.py
#files for 178nm after 3rd xenon run vacuum data were no longer in Vacuum_data_fitting.py, checking fits from above,
#all angles unshifted except 30->28, solid angle 2.15, background and mirror correction from January 9-12
# Out:
# Errors (log):  [0.01554678 0.01787779 0.01205953 0.01660998]
# Correlation matrix (log):
#  [[ 1.         -0.42220241 -0.26381503  0.00482927]
#  [-0.42220241  1.          0.79566935 -0.10386519]
#  [-0.26381503  0.79566935  1.         -0.38280973]
#  [ 0.00482927 -0.10386519 -0.38280973  1.        ]]
# Fit reduced chi^2:  1.4845651331101606
# Min and max values:
#  [[0.6282010274224926, 0.6480408776462844], [1.6825428670237876, 1.7073891386363738], [0.12116838634650666, 0.12412638217864132], [7.929484536057301, 8.197325968141284]]
# Fit parameters (rho_L, n, gamma): [0.638043842654382, 1.6948549566538027, 0.12263846636196879, 8.062293067198516]
# Fitting time: 464.2733771800995
# Plotting time: 11.60642695426941
# Reflectance calc time: 12.000451564788818

# %%
# %run Vacuum_data_fitting.py
#all angles unshifted except 30->28, background and mirror correction from January 9-12
#using solid angle 2.00 with correction factor 0.93133
# Out:
# Errors (log):  [0.01532561 0.01807892 0.01237023 0.0175757 ]
# Correlation matrix (log):
#  [[ 1.         -0.4029939  -0.25035012  0.01023117]
#  [-0.4029939   1.          0.79963292 -0.12457479]
#  [-0.25035012  0.79963292  1.         -0.40296204]
#  [ 0.01023117 -0.12457479 -0.40296204  1.        ]]
# Fit reduced chi^2:  1.4152950429062328
# Min and max values:
#  [[0.6874206041948685, 0.708817128204848], [1.716354729215245, 1.742730536152338], [0.11801913356556251, 0.12097539894155969], [7.915288593075467, 8.19846997412648]]
# Fit parameters (rho_L, n, gamma): [0.6980368890927242, 1.729423424428707, 0.11948812395309896, 8.055635038088248]
# Fitting time: 389.5790693759918
# Plotting time: 10.165677785873413
# Reflectance calc time: 10.008543968200684

# %%
# %run Vacuum_data_fitting.py
#all angles unshifted except 30->28, background and mirror correction from January 9-12
#using solid angle 2.00 with correction factor 0.93133, now with consterr = 20
# Out:
# Errors (log):  [0.00746185 0.01096655 0.00851132 0.01426914]
# Correlation matrix (log):
#  [[ 1.         -0.34815696 -0.24966073  0.03785066]
#  [-0.34815696  1.          0.7189788  -0.10536233]
#  [-0.24966073  0.7189788   1.         -0.41110959]
#  [ 0.03785066 -0.10536233 -0.41110959  1.        ]]
# Fit reduced chi^2:  3.8935541721829354
# Min and max values:
#  [[0.6723097871713879, 0.6824183800644567], [1.7157790907258184, 1.7316517799029416], [0.11994365286174209, 0.1220028875801355], [7.573643843559533, 7.792896306162948]]
# Fit parameters (rho_L, n, gamma): [0.6773452265004738, 1.7236719185838665, 0.12096888854594771, 7.682487952002843]
# Fitting time: 380.03090238571167
# Plotting time: 10.362361907958984
# Reflectance calc time: 9.124059677124023

# %%
# %run Vacuum_data_fitting.py
#all angles unshifted except 30->28, background and mirror correction from January 9-12
#using solid angle 2.00 with correction factor 0.93133, now with consterr = 40
# Out:
# Errors (log):  [0.00940723 0.01295736 0.00965834 0.01519569]
# Correlation matrix (log):
#  [[ 1.         -0.37128059 -0.24888732  0.02737758]
#  [-0.37128059  1.          0.75633308 -0.11363024]
#  [-0.24888732  0.75633308  1.         -0.40341166]
#  [ 0.02737758 -0.11363024 -0.40341166  1.        ]]
# Fit reduced chi^2:  2.694899479080502
# Min and max values:
#  [[0.681128586003354, 0.6940649613298715], [1.7174255400817866, 1.7362604246727877], [0.11968202055286505, 0.12201635314382202], [7.695030698348369, 7.932483225110619]]
# Fit parameters (rho_L, n, gamma): [0.6875663500383712, 1.7267819706154799, 0.12084355044744649, 7.812854915545257]
# Fitting time: 406.7248122692108
# Plotting time: 9.6383216381073
# Reflectance calc time: 9.029795408248901
