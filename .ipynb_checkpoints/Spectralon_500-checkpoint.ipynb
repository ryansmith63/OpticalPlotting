# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
#Jan 14 data
# Out:
# Errors (log):  [ 0.02417542  0.1093319   0.06263714]
# Correlation matrix (log):
#  [[ 1.         -0.37839804 -0.29581735]
#  [-0.37839804  1.          0.86807173]
#  [-0.29581735  0.86807173  1.        ]]
# Fit reduced chi^2:  0.0449709311804
# Min and max values:
#  [[0.65120733261702857, 0.68346737521500245], [1.1224917293435102, 1.1524302788934853], [0.20836707839984886, 0.23617560286411404]]
# Fit parameters (rho_L, n, gamma): [0.66714238835838002, 1.1366435086858375, 0.22183602132683145]
# Fitting time: 351.8337781429291
# Plotting time: 8.782047748565674
# Reflectance calc time: 4.944366455078125

# %%
# %run Vacuum_data_fitting.py
#Above with constant error changed from 100 to 20
# Out:
# Errors (log):  [ 0.00688476  0.03339141  0.0218859 ]
# Correlation matrix (log):
#  [[ 1.         -0.36181121 -0.28424059]
#  [-0.36181121  1.          0.79919918]
#  [-0.28424059  0.79919918  1.        ]]
# Fit reduced chi^2:  0.61938563925
# Min and max values:
#  [[0.65588674694105897, 0.66498046237910102], [1.1274304012306278, 1.1362311627100383], [0.20897541473203829, 0.2183257934060977]]
# Fit parameters (rho_L, n, gamma): [0.66041795270055292, 1.1317573213307524, 0.21359944574773732]
# Fitting time: 359.60471534729004
# Plotting time: 8.814920663833618
# Reflectance calc time: 5.22783350944519

# %%
# %run Vacuum_data_fitting.py
#Changed solid angle to 1.9
# Out:
# Errors (log):  [ 0.00683649  0.03564129  0.02201209]
# Correlation matrix (log):
#  [[ 1.         -0.32039103 -0.23941625]
#  [-0.32039103  1.          0.79693732]
#  [-0.23941625  0.79693732  1.        ]]
# Fit reduced chi^2:  0.556104054904
# Min and max values:
#  [[0.8466995308846661, 0.85835593962701495], [1.1621925651032183, 1.1741761046603489], [0.20007002724618156, 0.20907470384918481]]
# Fit parameters (rho_L, n, gamma): [0.85250781311039037, 1.1680775689809577, 0.20452281460901556]
# Fitting time: 340.2979965209961
# Plotting time: 8.792830467224121
# Reflectance calc time: 5.158886671066284

# %%
# %run Vacuum_data_fitting.py
#Changed solid angle to 1.7
# Out:
# Errors (log):  [ 0.00678339  0.03797571  0.02215513]
# Correlation matrix (log):
#  [[ 1.         -0.267283   -0.18533731]
#  [-0.267283    1.          0.79379405]
#  [-0.18533731  0.79379405  1.        ]]
# Fit reduced chi^2:  0.523803513116
# Min and max values:
#  [[1.0679965499207498, 1.0825845484190009], [1.2031760646169931, 1.2192087209170233], [0.19126298477373163, 0.1999284651271559]]
# Fit parameters (rho_L, n, gamma): [1.0752658102576338, 1.2110401981747685, 0.19554773069880088]
# Fitting time: 325.2996315956116
# Plotting time: 8.193541049957275
# Reflectance calc time: 5.681782245635986

# %%
print(y_total)
# Out:
# [0.9701380112756437, 0.9708562319391916, 0.9716128017194829, 0.9678697592543944]

# %%
# %run Vacuum_data_fitting.py
#Set use_second_order to True
