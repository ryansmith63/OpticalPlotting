# %%
import matplotlib.pyplot as plt

# %%
# %run Vacuum_data_fitting.py
#August 30 data
# Out:
# Errors (log):  [ 0.00729798  0.01758388  0.01306064  0.02194828]
# Correlation matrix (log):
#  [[ 1.         -0.37398566 -0.25760064  0.06496196]
#  [-0.37398566  1.          0.82231334 -0.23619657]
#  [-0.25760064  0.82231334  1.         -0.45021333]
#  [ 0.06496196 -0.23619657 -0.45021333  1.        ]]
# Fit reduced chi^2:  9.59837962625
# Min and max values:
#  [[0.82738302009179343, 0.83954802923463312], [1.7660416120254834, 1.7934608832086507], [0.14405565081096178, 0.14786814475304541], [8.8011212686243443, 9.1960651508656461]]
# Fit parameters (rho_L, n, gamma): [0.83344332977129532, 1.7796307164628127, 0.14594944955911776, 8.9964262119432057]
# Fitting time: 341.98805809020996
# Plotting time: 8.312886953353882
# Reflectance calc time: 11.608819007873535

# %%
# %run Vacuum_data_fitting.py
#November 26 data
# Out:
# Errors (log):  [ 0.00498037  0.01047719  0.00719273]
# Correlation matrix (log):
#  [[ 1.         -0.25487357 -0.17721798]
#  [-0.25487357  1.          0.7168661 ]
#  [-0.17721798  0.7168661   1.        ]]
# Fit reduced chi^2:  1.56181192626
# Min and max values:
#  [[0.88550795427881324, 0.89437233979610631], [1.5633546837619097, 1.5752839853682397], [0.11044980123654601, 0.11205015637041288]]
# Fit parameters (rho_L, n, gamma): [0.88992911008484588, 1.5692880884494387, 0.11124710108419006]
# Fitting time: 365.7656772136688
# Plotting time: 13.882079601287842
# Reflectance calc time: 14.641634702682495
