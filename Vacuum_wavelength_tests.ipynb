# %%
import matplotlib.pyplot as plt

wavelength = [178,255,310,400,500]
albedo = [0.688,0.91,0.908,0.832,0.681]
index = [1.73,1.17,1.11,1.24,1.29]
gamma = [0.121,0.067,0.031,0.081,0.088]
K = [7.813,-1,-1,7.759,6.49]
chi2 = [2.69,2.13,7.59,2.39,1.89]

# %%
plt.plot(wavelength,albedo)

# %%
plt.plot(wavelength,index)

# %%
plt.plot(wavelength,gamma)

# %%
plt.plot(wavelength,K)

# %%
plt.plot(wavelength,chi2)
